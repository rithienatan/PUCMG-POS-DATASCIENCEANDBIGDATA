# %% [markdown]
# ### CONFIGURAÇÃO/INSTALAÇÃO DO AMBIENTE

# %%
import sqlite3
import pandas as pd

# %%
# !pip install pyspark 
 
from pyspark.sql import SQLContext, SparkSession, functions as F 
from pyspark import SparkFiles
from pyspark.sql.types import * 
 
spark = SparkSession.builder.getOrCreate() 
sql = SQLContext(spark)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 47 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 67.0 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=962f529327fc2f1f97450f924465b620b3f8e7eca1c386a9cace573f112bae7d
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1
# /usr/local/lib/python3.8/dist-packages/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %% [markdown]
# ### CRIAÇÃO DE BANCO DE DADOS

# %% [markdown]
# #### PARA CRIAR BANCO DE DADOS, VOCÊ DEVE EXECUTAR O COMANDO
#
# ~~~python
# **nome_conexao_banco** = sqlite3.connect('**nome do arquivo do banco.db**')
# ~~~
#
# *   Se o banco já existir, ele irá conectar-se ao arquivo e permitirá usar os objetos já existentes.
# *   Se o banco não existir, ele será criado

# %%
conexao = sqlite3.connect('pedido_exame.db')

# %%
arquivo = 'DADOS_EXAMES.csv'
df = pd.read_csv(arquivo, delimiter=";")
df_exames = spark.read.format('csv').options(inferSchema=False, header=True, delimiter=';').load(arquivo)

# %% [markdown]
# #### PARA CRIAR TABELAS, VIEWS, PROCEDORES E QUAISQUER OUTROS OBJETOS, VOCÊ DEVE EXECUTAR A INSTRUÇÃO:
#
# ~~~python
# nome_conexao.execute('''
# CREATE TABLE nome_tabela (
#   campo1 tipo
# );
# ''')
# nome_conexao.commit()
# ~~~

# %%
conexao.execute('''
CREATE TABLE pedido_exame (
  IdUnidadeAtendimento INTEGER,
  Cidade VARCHAR(100),
  Estado VARCHAR(10),
  NumPedido VARCHAR(20),
  IdExame INTEGER,
  Exame VARCHAR(100),
  SiglaExame VARCHAR(100),
  Material VARCHAR(100),
  SetorExame VARCHAR(100),
  PrecoExame FLOAT,
  DataPedido VARCHAR(30),
  QtdExames INTEGER,
  QtdAmostrasColhidas INTERGER,
  DataPrevistaEntregaResultado VARCHAR(30),
  DataLiberacaoResultado VARCHAR(30)
);
''')
conexao.commit()

conexao.execute('''
CREATE TABLE logs_exames (
  IdAlteracao INTEGER PRIMARY KEY AUTOINCREMENT,
  IdUnidadeAtendimento INTEGER,
  Cidade VARCHAR(100),
  Estado VARCHAR(10),
  NumPedido VARCHAR(20),
  IdExame INTEGER,
  Exame VARCHAR(100),
  SiglaExame VARCHAR(100),
  Material VARCHAR(100),
  SetorExame VARCHAR(100),
  PrecoExame FLOAT,
  DataPedido VARCHAR(30),
  QtdExames INTEGER,
  QtdAmostrasColhidas INTERGER,
  DataPrevistaEntregaResultado VARCHAR(30),
  DataLiberacaoResultado VARCHAR(30)
);
''')
conexao.commit()

# %% [markdown]
# # ***Criando triggers***

# %%
conexao.execute('''
CREATE TRIGGER IF NOT EXISTS __logs_mudanca_pedido_exame_on_delete
AFTER DELETE 
ON pedido_exame

BEGIN
 INSERT INTO logs_exames (IdUnidadeAtendimento,Cidade,Estado,NumPedido,IdExame,Exame,SiglaExame,Material,SetorExame,PrecoExame,DataPedido,QtdExames,QtdAmostrasColhidas,DataPrevistaEntregaResultado,DataLiberacaoResultado)
   VALUES (
   old.IdUnidadeAtendimento,
   old.Cidade,
   old.Estado,
   old.NumPedido,
   old.IdExame,
   old.Exame,
   old.SiglaExame,
   old.Material,
   old.SetorExame,
   old.PrecoExame,
   old.DataPedido,
   old.QtdExames,
   old.QtdAmostrasColhidas,
   old.DataPrevistaEntregaResultado,
   old.DataLiberacaoResultado,
   'delete'
   );
END; 
''')
conexao.commit()

# %%
conexao.execute('''
CREATE TRIGGER IF NOT EXISTS __logs_mudanca_pedido_exame_on_update
AFTER UPDATE 
ON pedido_exame

BEGIN
 INSERT INTO logs_exames (IdUnidadeAtendimento,Cidade,Estado,NumPedido,IdExame,Exame,SiglaExame,Material,SetorExame,PrecoExame,DataPedido,QtdExames,QtdAmostrasColhidas,DataPrevistaEntregaResultado,DataLiberacaoResultado)
   VALUES (
   old.IdUnidadeAtendimento,
   old.Cidade,
   old.Estado,
   old.NumPedido,
   old.IdExame,
   old.Exame,
   old.SiglaExame,
   old.Material,
   old.SetorExame,
   old.PrecoExame,
   old.DataPedido,
   old.QtdExames,
   old.QtdAmostrasColhidas,
   old.DataPrevistaEntregaResultado,
   old.DataLiberacaoResultado,
   'update'
   );
END; 
''')
conexao.commit()

# %%
conexao.execute('''
CREATE TRIGGER IF NOT EXISTS __logs_mudanca_pedido_exame_on_insert
AFTER INSERT 
ON pedido_exame

BEGIN
 INSERT INTO logs_exames (IdUnidadeAtendimento,Cidade,Estado,NumPedido,IdExame,Exame,SiglaExame,Material,SetorExame,PrecoExame,DataPedido,QtdExames,QtdAmostrasColhidas,DataPrevistaEntregaResultado,DataLiberacaoResultado)
   VALUES (
   new.IdUnidadeAtendimento,
   new.Cidade,
   new.Estado,
   new.NumPedido,
   new.IdExame,
   new.Exame,
   new.SiglaExame,
   new.Material,
   new.SetorExame,
   new.PrecoExame,
   new.DataPedido,
   new.QtdExames,
   new.QtdAmostrasColhidas,
   new.DataPrevistaEntregaResultado,
   new.DataLiberacaoResultado,
   'insert'
   );
END; 
''')
conexao.commit()

# %% [markdown]
# #### PARA INSERIR REGISTROS, VOCÊ DEVER EXECUTAR A INSTRUÇÃO:
#
# ~~~python
# nome_conexao.execute('''
# INSERT INTO <nome da tabela> (campo1, campo2, campo3, ..., campoN) VALUES (valor1, valor2, valor3, ..., valorN)
# ''')
#
# nome_conexao.commit()
# ~~~
#
# SE ESTIVER CARREGANDO DADOS DE UM ARQUIVO, PODE EXECUTAR A INSTRUÇÃO POR MEIO DE UM LOOP FOR
#
# * Considere a estrutura do DataFrame mencionado a seguir uma estrutura PySpark. Para outras bibliotecas, você deverá adaptá-lo.
#
# ~~~python
# for linha in dataframe_dados.rdd.toLocalIterador():
#   nome_conexao.execute('INSERT INTO <nome da tabela> (campo1, campo2, campo3, ..., campoN) VALUES (' + str(linha.valor1) + ',\'' + str(linha.valor2) + ',\'' + str(linha.valor3) + ',\'') + str(linha...) + ',\'' + str(linha.valorN) + '\')')
#   nome_conexao.commit()
# ~~~

# %%
#for row in df_exames.rdd.toLocalIterator(): 
#  conexao_pedido_exame.execute('INSERT INTO pedido_exame (IdUnidadeAtendimento, Cidade, Estado, NumPedido, IdExame, Exame, SiglaExame, Material, SetorExame, PrecoExame, DataPedido, QtdExames, QtdAmostrasColhidas, DataPrevistaEntregaResultado, DataLiberacaoResultado) VALUES (' + str(row.IdUnidadeAtendimento) + ',\'' + str(row.Cidade) + '\',\'' + str(row.Estado) + '\',\'' + str(row.NumPedido) + '\',' + str(row.IdExame) + ',\'' + str(row.Exame) + '\',\'' + str(row.SiglaExame) + '\',\'' + str(row.Material) + '\',\'' + str(row.SetorExame) + '\',\'' + str(row.PrecoExame) + '\',\'' + str(row.DataPedido) + '\',' + str(row.QtdExames) + ',' + str(row.QtdAmostrasColhidas) + ',\'' + str(row.DataPrevistaEntregaResultado) + '\',\'' + str(row.DataLiberacaoResultado) + '\');') 
#  conexao_pedido_exame.commit()

df.to_sql('pedido_exame', conexao, if_exists='replace', index=False)

# %% [markdown]
# #### PARA ATUALIZAR DADOS, VOCÊ DEVE EXECUTAR A INSTRUÇÃO:
#
# ~~~python
# nome_conexao.execute('''
# UPDATE <nome da tabela>
# SET   campo1 = <novo valor>
# WHERE condicao ...
# ''')
#
# nome_conexao.commit()
# ~~~

# %%
conexao.execute('''
UPDATE pedido_exame
SET Cidade = 'Ipatinga'
WHERE IdExame = 6986
''')

conexao.commit()

# %% [markdown]
# #### PARA REMOVER REGISTROS, VOCÊ DEVE EXECUTAR A INSTRUÇÃO:
#
# ~~~python
# nome_conexao.execute('''
# DELETE
# FROM  <nome da tabela>
# WHERE condicao ...
# ''')
# ~~~

# %%
conexao.execute('''
DELETE
FROM  pedido_exame
WHERE IdExame = 8397
''')
conexao.commit()

# %% [markdown]
# #### PARA SELECIONAR DADOS, VOCÊ DEVE EXECUTAR A INSTRUÇÃO:
#
# ~~~python
# dados = nome_conexao.execute('''
# SELECT ...
# ''')
# nome_conexao.commit()
#
# for linha in dados:
#     print(linha)
# ~~~

# %%
dados = conexao.execute('''
select * from pedido_exame
WHERE IdExame = 6986
AND MATERIAL  = 'SANGUE'
''');

conexao.commit()
for linha in dados:
  print(linha)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# (7, 'Ipatinga', 'MG', 'PED-71478808', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-16 08:05:00', 1.0, 0.0, '2022-06-17 16:00:00', '2022-06-16 21:07:03')
# (7, 'Ipatinga', 'MG', 'PED-7264480', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:08:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 19:29:51')
# (6, 'Ipatinga', 'MG', 'PED-64167840', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 08:32:00', 1.0, 1.0, '2022-06-29 16:00:00', '2022-06-28 17:57:50')
# (7, 'Ipatinga', 'MG', 'PED-72025096', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 08:37:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-23 19:28:08')
# (6, 'Ipatinga', 'MG', 'PED-64969488', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 07:53:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 22:59:13')
# (7, 'Ipatinga', 'MG', 'PED-72491584', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 09:06:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 22:05:38')
# (7, 'Ipatinga', 'MG', 'PED-72556792', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 07:16:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-07-01 04:08:52')
# (7, 'Ipatinga', 'MG', 'PED-71420896', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 09:47:00', 1.0, 0.0, '2022-06-16 16:00:00', '2022-06-15 20:55:26')
# (7, 'Ipatinga', 'MG', 'PED-72564544', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 07:41:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-06-30 19:17:58')
# (7, 'Ipatinga', 'MG', 'PED-71189248', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-13 07:30:00', 1.0, 0.0, '2022-06-14 16:00:00', '2022-06-13 14:22:38')
# (6, 'Ipatinga', 'MG', 'PED-65059776', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 06:20:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 22:24:02')
# (7, 'Ipatinga', 'MG', 'PED-71491120', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-16 09:12:00', 1.0, 0.0, '2022-06-17 16:00:00', '2022-06-16 17:53:34')
# (7, 'Ipatinga', 'MG', 'PED-71757424', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 10:11:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 21:38:56')
# (7, 'Ipatinga', 'MG', 'PED-71636584', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 08:01:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 17:28:38')
# (8, 'Ipatinga', 'MG', 'PED-86330192', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 07:18:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 15:54:28')
# (8, 'Ipatinga', 'MG', 'PED-86338400', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 07:56:00', 1.0, 1.0, '2022-06-10 16:00:00', '2022-06-09 18:00:47')
# (7, 'Ipatinga', 'MG', 'PED-72109000', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 07:57:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-24 16:26:41')
# (8, 'Ipatinga', 'MG', 'PED-85855952', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 07:33:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-03 05:09:42')
# (8, 'Ipatinga', 'MG', 'PED-86369408', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 09:35:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 18:00:47')
# (7, 'Ipatinga', 'MG', 'PED-72185608', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-25 06:38:00', 1.0, 0.0, '2022-06-26 16:00:00', '2022-06-26 00:34:28')
# (8, 'Ipatinga', 'MG', 'PED-86423216', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 07:29:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 16:34:50')
# (8, 'Ipatinga', 'MG', 'PED-85903376', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 12:32:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 23:05:42')
# (11, 'Ipatinga', 'MG', 'PED-113508920', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:00:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 23:39:30')
# (11, 'Ipatinga', 'MG', 'PED-113907464', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 08:19:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 23:41:48')
# (6, 'Ipatinga', 'MG', 'PED-61099416', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 09:15:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 17:34:10')
# (6, 'Ipatinga', 'MG', 'PED-66355728', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 09:47:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 15:42:48')
# (6, 'Ipatinga', 'MG', 'PED-61578672', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 10:08:00', 1.0, 0.0, '2022-06-14 22:00:00', '2022-06-14 15:29:44')
# (6, 'Ipatinga', 'MG', 'PED-65629776', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 09:05:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 20:24:31')
# (6, 'Ipatinga', 'MG', 'PED-66029688', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:02:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 13:43:30')
# (6, 'Ipatinga', 'MG', 'PED-61145472', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 10:46:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 17:34:10')
# (6, 'Ipatinga', 'MG', 'PED-66391296', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 11:02:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 16:52:33')
# (6, 'Ipatinga', 'MG', 'PED-66097176', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 08:52:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 17:32:49')
# (6, 'Ipatinga', 'MG', 'PED-61212960', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-12 10:06:00', 1.0, 0.0, '2022-06-13 16:00:00', '2022-06-12 17:01:31')
# (6, 'Ipatinga', 'MG', 'PED-66119520', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 09:20:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 18:02:29')
# (6, 'Ipatinga', 'MG', 'PED-61735080', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 07:22:00', 1.0, 1.0, '2022-06-16 16:00:00', '2022-06-15 18:20:29')
# (6, 'Ipatinga', 'MG', 'PED-66510312', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 07:13:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-07 04:50:22')
# (7, 'Ipatinga', 'MG', 'PED-71189704', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-13 07:33:00', 1.0, 0.0, '2022-06-14 16:00:00', '2022-06-13 13:35:23')
# (7, 'Ipatinga', 'MG', 'PED-72368920', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 07:14:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 16:02:35')
# (7, 'Ipatinga', 'MG', 'PED-7932976', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 07:25:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 19:16:41')
# (6, 'Ipatinga', 'MG', 'PED-64841808', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 07:23:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 16:27:57')
# (7, 'Ipatinga', 'MG', 'PED-71924320', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 08:08:00', 1.0, 1.0, '2022-06-23 16:00:00', '2022-06-22 22:10:14')
# (7, 'Ipatinga', 'MG', 'PED-7966264', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 09:59:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 18:46:11')
# (7, 'Ipatinga', 'MG', 'PED-71010040', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 07:26:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 15:23:58')
# (7, 'Ipatinga', 'MG', 'PED-71026912', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 08:08:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 19:16:51')
# (11, 'Ipatinga', 'MG', 'PED-114484304', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 11:30:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 20:17:04')
# (8, 'Ipatinga', 'MG', 'PED-8975384', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 09:48:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 20:29:10')
# (11, 'Ipatinga', 'MG', 'PED-114218912', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:00:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-04 02:14:57')
# (8, 'Ipatinga', 'MG', 'PED-8656640', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 07:58:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-24 17:54:30')
# (7, 'Ipatinga', 'MG', 'PED-72233944', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-25 08:58:00', 1.0, 0.0, '2022-06-26 16:00:00', '2022-06-26 04:59:08')
# (11, 'Ipatinga', 'MG', 'PED-114264512', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:46:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 20:50:44')
# (11, 'Ipatinga', 'MG', 'PED-114277736', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:59:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 20:05:59')
# (11, 'Ipatinga', 'MG', 'PED-113817176', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 06:46:00', 1.0, 1.0, '2022-06-03 16:00:00', '2022-06-02 21:58:19')
# (11, 'Ipatinga', 'MG', 'PED-114336104', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 08:40:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 22:00:30')
# (8, 'Ipatinga', 'MG', 'PED-86275928', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-08 09:03:00', 1.0, 0.0, '2022-06-09 16:00:00', '2022-06-08 21:53:49')
# (11, 'Ipatinga', 'MG', 'PED-113942576', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 08:57:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 15:46:39')
# (11, 'Ipatinga', 'MG', 'PED-113946224', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 09:01:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-03 05:08:01')
# (11, 'Ipatinga', 'MG', 'PED-112006400', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-16 07:19:00', 1.0, 0.0, '2022-06-17 16:00:00', '2022-06-16 18:01:05')
# (11, 'Ipatinga', 'MG', 'PED-112019624', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-16 07:33:00', 1.0, 0.0, '2022-06-17 16:00:00', '2022-06-16 19:18:43')
# (11, 'Ipatinga', 'MG', 'PED-111476072', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 11:24:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 23:34:25')
# (11, 'Ipatinga', 'MG', 'PED-112072064', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-16 08:25:00', 1.0, 0.0, '2022-06-17 16:00:00', '2022-06-16 16:20:04')
# (11, 'Ipatinga', 'MG', 'PED-11234384', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 08:16:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 18:13:56')
# (11, 'Ipatinga', 'MG', 'PED-116246288', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 06:38:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 20:10:24')
# (11, 'Ipatinga', 'MG', 'PED-11263568', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 08:50:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-11 00:07:10')
# (11, 'Ipatinga', 'MG', 'PED-11265848', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 08:52:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 20:13:14')
# (11, 'Ipatinga', 'MG', 'PED-114568664', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 08:14:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-25 00:04:13')
# (11, 'Ipatinga', 'MG', 'PED-11366624', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 10:33:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 21:55:17')
# (11, 'Ipatinga', 'MG', 'PED-114611984', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 09:07:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-25 00:06:13')
# (11, 'Ipatinga', 'MG', 'PED-11466488', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 12:15:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 18:36:00')
# (11, 'Ipatinga', 'MG', 'PED-114634784', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 09:26:00', 1.0, 0.0, '2022-06-27 17:00:00', '2022-06-24 16:09:21')
# (11, 'Ipatinga', 'MG', 'PED-111364808', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 09:04:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-15 08:50:27')
# (11, 'Ipatinga', 'MG', 'PED-113525792', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 07:15:00', 1.0, 0.0, '2022-06-23 16:00:00', '2022-06-22 23:07:36')
# (11, 'Ipatinga', 'MG', 'PED-115980896', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 08:02:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 17:20:30')
# (11, 'Ipatinga', 'MG', 'PED-115987280', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 08:08:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 18:51:18')
# (11, 'Ipatinga', 'MG', 'PED-111397640', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 09:41:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 20:54:05')
# (11, 'Ipatinga', 'MG', 'PED-113689040', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 09:57:00', 1.0, 0.0, '2022-06-26 16:00:00', '2022-06-25 14:50:57')
# (11, 'Ipatinga', 'MG', 'PED-115575968', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 07:12:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-29 11:38:53')
# (11, 'Ipatinga', 'MG', 'PED-115583720', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 07:19:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 21:38:52')
# (11, 'Ipatinga', 'MG', 'PED-115319240', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 09:58:00', 1.0, 0.0, '2022-06-28 16:00:00', '2022-06-27 21:52:55')
# (11, 'Ipatinga', 'MG', 'PED-113613344', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 08:43:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-24 16:36:23')
# (0, 'Ipatinga', 'MG', 'PED-0647064', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 08:12:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-23 20:48:03')
# (0, 'Ipatinga', 'MG', 'PED-06424128', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-19 08:18:00', 1.0, 1.0, '2022-06-20 16:00:00', '2022-06-19 11:48:01')
# (0, 'Ipatinga', 'MG', 'PED-0569544', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 06:47:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 15:14:10')
# (0, 'Ipatinga', 'MG', 'PED-0156864', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 08:36:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 13:06:53')
# (0, 'Ipatinga', 'MG', 'PED-0607848', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 07:34:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-22 04:16:59')
# (0, 'Ipatinga', 'MG', 'PED-0725952', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 09:49:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 14:29:38')
# (0, 'Ipatinga', 'MG', 'PED-0787512', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 11:00:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 18:45:47')
# (6, 'Ipatinga', 'MG', 'PED-64664880', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 09:08:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-06-30 17:58:40')
# (6, 'Ipatinga', 'MG', 'PED-64168752', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 07:31:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-29 05:26:13')
# (6, 'Ipatinga', 'MG', 'PED-62559528', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 08:03:00', 1.0, 1.0, '2022-06-21 16:00:00', '2022-06-20 12:25:31')
# (6, 'Ipatinga', 'MG', 'PED-64405872', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 07:59:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-02 02:04:09')
# (6, 'Ipatinga', 'MG', 'PED-64407696', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:03:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 16:57:53')
# (6, 'Ipatinga', 'MG', 'PED-64014168', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 11:39:00', 1.0, 0.0, '2022-06-28 16:00:00', '2022-06-27 15:30:59')
# (6, 'Ipatinga', 'MG', 'PED-64406328', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 07:59:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 20:11:56')
# (6, 'Ipatinga', 'MG', 'PED-64106736', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 06:21:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-29 05:44:48')
# (6, 'Ipatinga', 'MG', 'PED-64204776', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 08:45:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 20:18:37')
# (6, 'Ipatinga', 'MG', 'PED-64413168', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:22:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 20:51:04')
# (6, 'Ipatinga', 'MG', 'PED-62201568', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-17 09:20:00', 1.0, 0.0, '2022-06-18 16:00:00', '2022-06-17 23:02:55')
# (6, 'Ipatinga', 'MG', 'PED-64419096', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:44:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-02 02:04:09')
# (7, 'Ipatinga', 'MG', 'PED-7649344', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 07:39:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 14:09:37')
# (7, 'Ipatinga', 'MG', 'PED-7364344', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 07:54:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 20:32:24')
# (7, 'Ipatinga', 'MG', 'PED-71374840', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 07:25:00', 1.0, 0.0, '2022-06-16 16:00:00', '2022-06-15 15:03:06')
# (7, 'Ipatinga', 'MG', 'PED-7374376', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 08:27:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 14:35:03')
# (7, 'Ipatinga', 'MG', 'PED-7303696', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 10:24:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 19:30:51')
# (6, 'Ipatinga', 'MG', 'PED-64465608', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 07:02:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 15:58:05')
# (7, 'Ipatinga', 'MG', 'PED-71921584', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 08:03:00', 1.0, 0.0, '2022-06-23 16:00:00', '2022-06-23 00:00:53')
# (6, 'Ipatinga', 'MG', 'PED-64490232', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 09:02:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 15:58:05')
# (8, 'Ipatinga', 'MG', 'PED-86515328', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 08:30:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 18:28:54')
# (8, 'Ipatinga', 'MG', 'PED-86564576', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-13 07:06:00', 1.0, 0.0, '2022-06-14 16:00:00', '2022-06-13 19:44:33')
# (7, 'Ipatinga', 'MG', 'PED-72037408', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 09:15:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-23 19:28:38')
# (8, 'Ipatinga', 'MG', 'PED-86614280', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-13 13:03:00', 1.0, 0.0, '2022-06-14 16:00:00', '2022-06-13 20:09:09')
# (6, 'Ipatinga', 'MG', 'PED-65805336', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 08:47:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 15:29:56')
# (8, 'Ipatinga', 'MG', 'PED-821888', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 08:25:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 17:09:20')
# (8, 'Ipatinga', 'MG', 'PED-836024', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 09:27:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 17:52:19')
# (8, 'Ipatinga', 'MG', 'PED-86131832', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 09:44:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-07 04:47:19')
# (7, 'Ipatinga', 'MG', 'PED-72404944', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 08:54:00', 1.0, 0.0, '2022-06-28 19:00:00', '2022-06-28 17:31:04')
# (8, 'Ipatinga', 'MG', 'PED-86637536', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 06:57:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 21:52:58')
# (11, 'Ipatinga', 'MG', 'PED-114736928', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:20:00', 1.0, 0.0, '2022-06-07 17:00:00', '2022-06-06 09:03:00')
# (11, 'Ipatinga', 'MG', 'PED-115099448', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 10:13:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 18:37:45')
# (11, 'Ipatinga', 'MG', 'PED-113426384', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 05:46:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-02 11:44:10')
# (11, 'Ipatinga', 'MG', 'PED-113482016', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 07:32:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-02 01:34:56')
# (11, 'Ipatinga', 'MG', 'PED-114901544', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 06:51:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 15:09:45')
# (11, 'Ipatinga', 'MG', 'PED-113991368', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 08:07:00', 1.0, 0.0, '2022-06-24 17:00:00', '2022-06-23 15:53:58')
# (11, 'Ipatinga', 'MG', 'PED-111635672', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 07:46:00', 1.0, 0.0, '2022-06-16 16:00:00', '2022-06-16 04:41:02')
# (11, 'Ipatinga', 'MG', 'PED-115880120', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-08 09:37:00', 1.0, 0.0, '2022-06-09 16:00:00', '2022-06-08 17:50:31')
# (11, 'Ipatinga', 'MG', 'PED-113180144', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 09:11:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-22 00:46:25')
# (11, 'Ipatinga', 'MG', 'PED-114018272', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 08:33:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-24 09:37:50')
# (11, 'Ipatinga', 'MG', 'PED-115894712', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-08 09:48:00', 1.0, 0.0, '2022-06-09 16:00:00', '2022-06-08 18:02:52')
# (11, 'Ipatinga', 'MG', 'PED-112241240', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-17 08:09:00', 1.0, 0.0, '2022-06-20 16:00:00', '2022-06-17 17:21:39')
# (11, 'Ipatinga', 'MG', 'PED-113519864', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 07:07:00', 1.0, 0.0, '2022-06-23 16:00:00', '2022-06-22 20:22:34')
# (11, 'Ipatinga', 'MG', 'PED-111690392', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 08:43:00', 1.0, 0.0, '2022-06-16 16:00:00', '2022-06-16 10:47:24')
# (11, 'Ipatinga', 'MG', 'PED-111691304', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 08:44:00', 1.0, 0.0, '2022-06-17 16:00:00', '2022-06-16 13:21:52')
# (0, 'Ipatinga', 'MG', 'PED-06339768', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 09:56:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 17:58:33')
# (0, 'Ipatinga', 'MG', 'PED-06267264', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:41:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-05 05:51:19')
# (0, 'Ipatinga', 'MG', 'PED-06464712', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 12:47:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:21:22')
# (0, 'Ipatinga', 'MG', 'PED-06281856', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:55:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 16:47:41')
# (0, 'Ipatinga', 'MG', 'PED-06241728', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:10:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 17:09:03')
# (0, 'Ipatinga', 'MG', 'PED-0456', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-05 07:35:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 16:34:27')
# (0, 'Ipatinga', 'MG', 'PED-0395808', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 07:52:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 14:09:37')
# (0, 'Ipatinga', 'MG', 'PED-061104', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-05 08:58:00', 1.0, 0.0, '2022-06-06 16:00:00', '2022-06-05 00:00:00')
# (0, 'Ipatinga', 'MG', 'PED-0187872', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-05 11:15:00', 1.0, 0.0, '2022-06-06 16:00:00', '2022-06-05 00:00:00')
# (0, 'Ipatinga', 'MG', 'PED-06626136', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-05 06:51:00', 1.0, 0.0, '2022-06-06 16:00:00', '2022-06-05 12:47:40')
# (0, 'Ipatinga', 'MG', 'PED-0277704', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-05 13:46:00', 1.0, 0.0, '2022-06-06 16:00:00', '2022-06-05 00:00:00')
# (0, 'Ipatinga', 'MG', 'PED-0336072', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 06:20:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 13:02:20')
# (0, 'Ipatinga', 'MG', 'PED-0339264', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 06:24:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 13:02:20')
# (0, 'Ipatinga', 'MG', 'PED-0365712', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 07:15:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-07 03:25:38')
# (0, 'Ipatinga', 'MG', 'PED-03896520', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 06:58:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 15:03:35')
# (0, 'Ipatinga', 'MG', 'PED-04529448', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 09:44:00', 1.0, 0.0, '2022-06-29 22:00:00', '2022-06-29 17:19:30')
# (0, 'Ipatinga', 'MG', 'PED-04925712', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 08:00:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-07-01 04:03:51')
# (0, 'Ipatinga', 'MG', 'PED-03421824', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 07:20:00', 1.0, 0.0, '2022-06-28 16:00:00', '2022-06-27 16:48:37')
# (0, 'Ipatinga', 'MG', 'PED-04938480', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 08:14:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-06-30 14:39:44')
# (0, 'Ipatinga', 'MG', 'PED-04975872', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 08:52:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-06-30 12:44:56')
# (0, 'Ipatinga', 'MG', 'PED-04537200', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 09:52:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 16:56:49')
# (0, 'Ipatinga', 'MG', 'PED-04902912', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 07:39:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-06-30 20:43:17')
# (0, 'Ipatinga', 'MG', 'PED-05064792', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 10:47:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-06-30 19:47:34')
# (0, 'Ipatinga', 'MG', 'PED-06426864', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-19 08:23:00', 1.0, 0.0, '2022-06-20 16:00:00', '2022-06-19 14:37:28')
# (0, 'Ipatinga', 'MG', 'PED-06394488', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-19 07:26:00', 1.0, 0.0, '2022-06-20 16:00:00', '2022-06-19 12:31:40')
# (0, 'Ipatinga', 'MG', 'PED-0222072', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 09:58:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 17:31:32')
# (0, 'Ipatinga', 'MG', 'PED-06498912', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-19 10:02:00', 1.0, 0.0, '2022-06-20 16:00:00', '2022-06-19 16:22:08')
# (0, 'Ipatinga', 'MG', 'PED-06395856', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-19 07:30:00', 1.0, 0.0, '2022-06-20 16:00:00', '2022-06-19 14:36:58')
# (0, 'Ipatinga', 'MG', 'PED-0601920', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 07:27:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 19:55:05')
# (0, 'Ipatinga', 'MG', 'PED-06423672', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-19 08:16:00', 1.0, 0.0, '2022-06-20 16:00:00', '2022-06-19 19:24:48')
# (0, 'Ipatinga', 'MG', 'PED-0145920', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 08:26:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 13:20:30')
# (0, 'Ipatinga', 'MG', 'PED-0661200', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 08:27:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 19:30:29')
# (0, 'Ipatinga', 'MG', 'PED-0621528', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 07:45:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 14:29:38')
# (0, 'Ipatinga', 'MG', 'PED-0553584', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 06:21:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 15:14:10')
# (0, 'Ipatinga', 'MG', 'PED-0779304', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 10:47:00', 1.0, 0.0, '2022-06-21 22:00:00', '2022-06-21 17:42:49')
# (1, 'Ipatinga', 'MG', 'PED-14765200', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-08 08:22:00', 1.0, 0.0, '2022-06-09 16:00:00', '2022-06-09 06:51:44')
# (1, 'Ipatinga', 'MG', 'PED-14062048', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 06:48:00', 1.0, 1.0, '2022-06-04 16:00:00', '2022-06-03 14:22:27')
# (1, 'Ipatinga', 'MG', 'PED-14777056', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-08 08:45:00', 1.0, 0.0, '2022-06-09 16:00:00', '2022-06-08 20:47:02')
# (1, 'Ipatinga', 'MG', 'PED-14628856', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-07 10:02:00', 1.0, 0.0, '2022-06-08 16:00:00', '2022-06-07 19:18:06')
# (1, 'Ipatinga', 'MG', 'PED-14082568', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:31:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 14:53:43')
# (1, 'Ipatinga', 'MG', 'PED-14085304', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:35:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 13:59:39')
# (1, 'Ipatinga', 'MG', 'PED-14223928', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 06:11:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 19:48:21')
# (1, 'Ipatinga', 'MG', 'PED-14969032', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 08:17:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-10 01:03:41')
# (1, 'Ipatinga', 'MG', 'PED-13790272', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 10:24:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-02 02:02:36')
# (1, 'Ipatinga', 'MG', 'PED-14240344', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 06:59:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:07:47')
# (1, 'Ipatinga', 'MG', 'PED-14301448', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:55:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-05 06:17:55')
# (1, 'Ipatinga', 'MG', 'PED-13697248', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 06:51:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 14:09:55')
# (1, 'Ipatinga', 'MG', 'PED-14186080', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 13:05:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 21:05:48')
# (1, 'Ipatinga', 'MG', 'PED-16050664', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 08:44:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 14:04:40')
# (1, 'Ipatinga', 'MG', 'PED-13748776', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:49:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 23:13:58')
# (1, 'Ipatinga', 'MG', 'PED-13745128', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:40:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-02 02:01:50')
# (1, 'Ipatinga', 'MG', 'PED-14327896', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 09:53:00', 1.0, 0.0, '2022-06-05 15:00:00', '2022-06-04 19:38:38')
# (2, 'Ipatinga', 'MG', 'PED-246512', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 07:12:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 12:10:18')
# (2, 'Ipatinga', 'MG', 'PED-2903336', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 07:48:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 15:02:33')
# (2, 'Ipatinga', 'MG', 'PED-26556368', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 07:52:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 18:58:22')
# (1, 'Ipatinga', 'MG', 'PED-11269048', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 07:05:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 14:08:27')
# (1, 'Ipatinga', 'MG', 'PED-11277712', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 07:25:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 15:28:50')
# (1, 'Ipatinga', 'MG', 'PED-11290936', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 07:57:00', 1.0, 1.0, '2022-06-30 16:00:00', '2022-06-29 14:08:59')
# (2, 'Ipatinga', 'MG', 'PED-2830376', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-17 10:36:00', 1.0, 0.0, '2022-06-18 16:00:00', '2022-06-17 15:29:43')
# (2, 'Ipatinga', 'MG', 'PED-231464', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 06:23:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-10 11:44:30')
# (2, 'Ipatinga', 'MG', 'PED-250616', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 07:23:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-11 05:07:00')
# (2, 'Ipatinga', 'MG', 'PED-2152760', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 06:20:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 12:54:07')
# (2, 'Ipatinga', 'MG', 'PED-25577336', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 06:29:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 13:52:30')
# (2, 'Ipatinga', 'MG', 'PED-26040176', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:12:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 16:49:38')
# (2, 'Ipatinga', 'MG', 'PED-26044280', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:23:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:13:36')
# (2, 'Ipatinga', 'MG', 'PED-26107664', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 06:19:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-07 04:46:49')
# (2, 'Ipatinga', 'MG', 'PED-26075744', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 09:56:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:13:36')
# (1, 'Ipatinga', 'MG', 'PED-11244424', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 16:25:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 21:03:45')
# (2, 'Ipatinga', 'MG', 'PED-26041088', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:12:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 18:34:30')
# (1, 'Ipatinga', 'MG', 'PED-11312824', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 08:51:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 20:21:08')
# (2, 'Ipatinga', 'MG', 'PED-25617464', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:26:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-02 02:08:00')
# (2, 'Ipatinga', 'MG', 'PED-26065712', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 09:27:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 16:49:38')
# (2, 'Ipatinga', 'MG', 'PED-21547664', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 09:36:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-23 23:11:34')
# (2, 'Ipatinga', 'MG', 'PED-2873696', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 08:16:00', 1.0, 1.0, '2022-06-16 16:00:00', '2022-06-15 18:13:33')
# (2, 'Ipatinga', 'MG', 'PED-21009128', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-17 07:22:00', 1.0, 0.0, '2022-06-18 16:00:00', '2022-06-17 11:15:06')
# (2, 'Ipatinga', 'MG', 'PED-21117200', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 07:55:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 20:40:40')
# (2, 'Ipatinga', 'MG', 'PED-26617472', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 07:28:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 11:48:07')
# (2, 'Ipatinga', 'MG', 'PED-21159152', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 11:03:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 14:23:12')
# (2, 'Ipatinga', 'MG', 'PED-21672152', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 10:18:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-24 23:05:47')
# (2, 'Ipatinga', 'MG', 'PED-2959880', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-16 07:51:00', 1.0, 0.0, '2022-06-17 16:00:00', '2022-06-16 14:46:45')
# (2, 'Ipatinga', 'MG', 'PED-21207032', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 09:11:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 14:48:00')
# (2, 'Ipatinga', 'MG', 'PED-2539904', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 07:18:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 22:51:41')
# (2, 'Ipatinga', 'MG', 'PED-26202512', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 07:31:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 11:23:17')
# (2, 'Ipatinga', 'MG', 'PED-21228464', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 10:47:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 22:44:03')
# (2, 'Ipatinga', 'MG', 'PED-26207072', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 07:46:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 16:16:36')
# (2, 'Ipatinga', 'MG', 'PED-2714096', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 06:32:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 22:19:01')
# (2, 'Ipatinga', 'MG', 'PED-26213000', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:11:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 15:02:57')
# (2, 'Ipatinga', 'MG', 'PED-2724584', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 07:10:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 14:36:26')
# (2, 'Ipatinga', 'MG', 'PED-2577752', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 09:14:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 19:26:10')
# (2, 'Ipatinga', 'MG', 'PED-21288200', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 07:59:00', 1.0, 0.0, '2022-06-23 16:00:00', '2022-06-22 20:39:40')
# (2, 'Ipatinga', 'MG', 'PED-21487472', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 06:04:00', 1.0, 1.0, '2022-06-24 16:00:00', '2022-06-23 21:00:04')
# (2, 'Ipatinga', 'MG', 'PED-2585504', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 09:48:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 20:09:43')
# (2, 'Ipatinga', 'MG', 'PED-21523952', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 07:56:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-23 18:00:35')
# (3, 'Ipatinga', 'MG', 'PED-31841784', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-25 08:14:00', 1.0, 0.0, '2022-06-26 16:00:00', '2022-06-25 15:08:31')
# (3, 'Ipatinga', 'MG', 'PED-31049256', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 06:39:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 13:41:07')
# (3, 'Ipatinga', 'MG', 'PED-31853640', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-25 08:51:00', 1.0, 0.0, '2022-06-26 16:00:00', '2022-06-25 14:12:50')
# (4, 'Ipatinga', 'MG', 'PED-4802104', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 07:36:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 17:58:33')
# (4, 'Ipatinga', 'MG', 'PED-4808944', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 09:20:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 18:26:42')
# (8, 'Ipatinga', 'MG', 'PED-8555864', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 06:18:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-23 15:56:11')
# (8, 'Ipatinga', 'MG', 'PED-8116280', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 09:05:00', 1.0, 0.0, '2022-06-16 16:00:00', '2022-06-15 20:46:24')
# (8, 'Ipatinga', 'MG', 'PED-8225264', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-17 09:30:00', 1.0, 1.0, '2022-06-18 16:00:00', '2022-06-17 14:57:58')
# (11, 'Ipatinga', 'MG', 'PED-114248552', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:32:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 20:05:59')
# (11, 'Ipatinga', 'MG', 'PED-11614688', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 06:51:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 22:27:37')
# (8, 'Ipatinga', 'MG', 'PED-8921120', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 06:25:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 16:02:05')
# (11, 'Ipatinga', 'MG', 'PED-11269496', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 08:57:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-11 04:44:47')
# (11, 'Ipatinga', 'MG', 'PED-111233480', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 06:45:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-15 08:48:26')
# (11, 'Ipatinga', 'MG', 'PED-115866440', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-08 09:27:00', 1.0, 0.0, '2022-06-09 16:00:00', '2022-06-08 21:31:46')
# (11, 'Ipatinga', 'MG', 'PED-115250384', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-07 06:32:00', 1.0, 0.0, '2022-06-08 16:00:00', '2022-06-07 22:56:34')
# (11, 'Ipatinga', 'MG', 'PED-11339264', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 10:14:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-11 04:45:47')
# (11, 'Ipatinga', 'MG', 'PED-111404024', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 09:52:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 20:23:32')
# (11, 'Ipatinga', 'MG', 'PED-111432296', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 10:32:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 22:22:01')
# (11, 'Ipatinga', 'MG', 'PED-111450536', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 10:56:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 23:51:30')
# (11, 'Ipatinga', 'MG', 'PED-113160080', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 08:52:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 13:09:55')
# (11, 'Ipatinga', 'MG', 'PED-115197488', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 13:56:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 21:16:56')
# (0, 'Ipatinga', 'MG', 'PED-0967176', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 16:49:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-22 00:52:57')
# (0, 'Ipatinga', 'MG', 'PED-01051536', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 06:29:00', 1.0, 0.0, '2022-06-23 16:00:00', '2022-06-23 00:00:53')
# (0, 'Ipatinga', 'MG', 'PED-0623808', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 07:49:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 15:14:11')
# (0, 'Ipatinga', 'MG', 'PED-01059288', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 06:43:00', 1.0, 1.0, '2022-06-23 16:00:00', '2022-06-22 15:22:50')
# (0, 'Ipatinga', 'MG', 'PED-0637488', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 08:01:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 15:14:11')
# (0, 'Ipatinga', 'MG', 'PED-0657096', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 08:21:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-22 04:16:59')
# (0, 'Ipatinga', 'MG', 'PED-0630192', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 07:56:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 15:14:11')
# (0, 'Ipatinga', 'MG', 'PED-0578208', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 07:03:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 15:14:11')
# (0, 'Ipatinga', 'MG', 'PED-078888', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 07:10:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 13:06:22')
# (0, 'Ipatinga', 'MG', 'PED-01114008', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 07:47:00', 1.0, 0.0, '2022-06-23 16:00:00', '2022-06-22 20:39:40')
# (0, 'Ipatinga', 'MG', 'PED-0576384', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 06:58:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 19:29:59')
# (0, 'Ipatinga', 'MG', 'PED-0676704', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 08:46:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 16:33:21')
# (1, 'Ipatinga', 'MG', 'PED-1285912', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 07:44:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-09 19:05:52')
# (1, 'Ipatinga', 'MG', 'PED-1520296', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-13 06:12:00', 1.0, 0.0, '2022-06-14 16:00:00', '2022-06-13 15:28:25')
# (1, 'Ipatinga', 'MG', 'PED-113680', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-06 07:43:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 19:56:53')
# ...
# (4, 'Ipatinga', 'MG', 'PED-4827184', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 08:36:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 23:24:52')
# (4, 'Ipatinga', 'MG', 'PED-43930720', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 06:31:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 13:23:32')
# (4, 'Ipatinga', 'MG', 'PED-46585096', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 07:06:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-05 05:54:19')
# (4, 'Ipatinga', 'MG', 'PED-46588744', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 07:21:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 19:29:53')
# (4, 'Ipatinga', 'MG', 'PED-46593760', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 07:39:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:02:56')
# (4, 'Ipatinga', 'MG', 'PED-4625632', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 08:16:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 23:40:51')
# (4, 'Ipatinga', 'MG', 'PED-46610176', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:26:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:03:54')
# (4, 'Ipatinga', 'MG', 'PED-43951240', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 07:53:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 22:51:03')
# (5, 'Ipatinga', 'MG', 'PED-5687192', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 06:20:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-11 04:54:17')
# (5, 'Ipatinga', 'MG', 'PED-56472920', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 06:46:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-03 00:11:55')
# (5, 'Ipatinga', 'MG', 'PED-51017792', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 06:41:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-14 20:08:30')
# (4, 'Ipatinga', 'MG', 'PED-41424544', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 09:38:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 21:22:51')
# (5, 'Ipatinga', 'MG', 'PED-5103056', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 06:13:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 15:31:47')
# (5, 'Ipatinga', 'MG', 'PED-51058832', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-14 09:01:00', 1.0, 0.0, '2022-06-15 16:00:00', '2022-06-15 08:55:06')
# (5, 'Ipatinga', 'MG', 'PED-52125872', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 09:50:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-24 04:02:09')
# (5, 'Ipatinga', 'MG', 'PED-52101248', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 08:44:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-23 19:29:08')
# (5, 'Ipatinga', 'MG', 'PED-52198832', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 06:44:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-24 21:07:51')
# (6, 'Ipatinga', 'MG', 'PED-62511648', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 06:21:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 12:25:30')
# (6, 'Ipatinga', 'MG', 'PED-64166016', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 06:47:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 19:21:30')
# (6, 'Ipatinga', 'MG', 'PED-64411800', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:18:00', 1.0, 0.0, '2022-06-02 16:00:00', '2022-06-01 22:53:52')
# (6, 'Ipatinga', 'MG', 'PED-64223016', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 07:50:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-07-01 04:25:24')
# (6, 'Ipatinga', 'MG', 'PED-62587344', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-20 09:00:00', 1.0, 0.0, '2022-06-21 16:00:00', '2022-06-20 12:04:21')
# (6, 'Ipatinga', 'MG', 'PED-61865040', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 11:19:00', 1.0, 1.0, '2022-06-16 16:00:00', '2022-06-15 20:48:55')
# (8, 'Ipatinga', 'MG', 'PED-86493896', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 07:08:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 12:54:07')
# (11, 'Ipatinga', 'MG', 'PED-113514848', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-01 08:07:00', 1.0, 0.0, '2022-06-02 17:00:00', '2022-06-01 14:50:45')
# (7, 'Ipatinga', 'MG', 'PED-71381224', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-15 07:45:00', 1.0, 0.0, '2022-06-16 16:00:00', '2022-06-15 15:18:38')
# (8, 'Ipatinga', 'MG', 'PED-8869136', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 08:09:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-29 05:38:47')
# (8, 'Ipatinga', 'MG', 'PED-8279984', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 07:59:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 15:50:12')
# (8, 'Ipatinga', 'MG', 'PED-8281808', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 08:02:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 21:00:14')
# (8, 'Ipatinga', 'MG', 'PED-86524448', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 09:02:00', 1.0, 1.0, '2022-06-14 16:00:00', '2022-06-12 01:45:19')
# (8, 'Ipatinga', 'MG', 'PED-8881448', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 08:53:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 17:01:29')
# (8, 'Ipatinga', 'MG', 'PED-8903336', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 11:13:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 20:01:06')
# (8, 'Ipatinga', 'MG', 'PED-86541320', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 09:53:00', 1.0, 1.0, '2022-06-12 16:00:00', '2022-06-11 20:49:56')
# (8, 'Ipatinga', 'MG', 'PED-86416376', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-10 07:07:00', 1.0, 0.0, '2022-06-11 16:00:00', '2022-06-11 05:03:52')
# (8, 'Ipatinga', 'MG', 'PED-8937080', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-29 07:31:00', 1.0, 0.0, '2022-06-30 16:00:00', '2022-06-29 16:02:05')
# (8, 'Ipatinga', 'MG', 'PED-8488376', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-22 07:20:00', 1.0, 1.0, '2022-06-23 16:00:00', '2022-06-22 21:57:09')
# (8, 'Ipatinga', 'MG', 'PED-8860472', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 07:36:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 18:31:50')
# (7, 'Ipatinga', 'MG', 'PED-71092120', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 06:33:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 14:40:06')
# (8, 'Ipatinga', 'MG', 'PED-86019200', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 06:49:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:11:40')
# (8, 'Ipatinga', 'MG', 'PED-8886920', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-28 09:12:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-29 05:39:47')
# (8, 'Ipatinga', 'MG', 'PED-81032840', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 08:14:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-06-30 18:29:21')
# (7, 'Ipatinga', 'MG', 'PED-71102608', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 07:15:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 14:40:06')
# (8, 'Ipatinga', 'MG', 'PED-86039720', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:14:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:12:38')
# (11, 'Ipatinga', 'MG', 'PED-114721424', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:03:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 21:34:10')
# (11, 'Ipatinga', 'MG', 'PED-115271360', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-07 07:02:00', 1.0, 0.0, '2022-06-08 16:00:00', '2022-06-07 22:12:56')
# (11, 'Ipatinga', 'MG', 'PED-114755624', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:45:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 18:32:34')
# (11, 'Ipatinga', 'MG', 'PED-11652536', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 07:33:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 17:29:06')
# (11, 'Ipatinga', 'MG', 'PED-114768392', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 09:02:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 15:48:26')
# (11, 'Ipatinga', 'MG', 'PED-116553632', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 11:37:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-10 01:02:11')
# (11, 'Ipatinga', 'MG', 'PED-114695432', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 07:37:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 13:31:50')
# (11, 'Ipatinga', 'MG', 'PED-116370320', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-09 08:38:00', 1.0, 0.0, '2022-06-10 16:00:00', '2022-06-10 01:02:11')
# (11, 'Ipatinga', 'MG', 'PED-11674880', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 07:58:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 23:41:21')
# (11, 'Ipatinga', 'MG', 'PED-115324256', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-07 07:52:00', 1.0, 0.0, '2022-06-08 16:00:00', '2022-06-07 20:32:15')
# (11, 'Ipatinga', 'MG', 'PED-11692208', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 08:15:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-12 09:03:34')
# (11, 'Ipatinga', 'MG', 'PED-114827672', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 10:19:00', 1.0, 0.0, '2022-06-07 16:00:00', '2022-06-06 21:04:27')
# (11, 'Ipatinga', 'MG', 'PED-114726896', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 08:08:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 15:20:00')
# (11, 'Ipatinga', 'MG', 'PED-115218008', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 07:56:00', 1.0, 0.0, '2022-06-28 17:00:00', '2022-06-27 12:51:57')
# (11, 'Ipatinga', 'MG', 'PED-113168744', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-21 08:59:00', 1.0, 0.0, '2022-06-22 16:00:00', '2022-06-21 16:13:40')
# (11, 'Ipatinga', 'MG', 'PED-115239440', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 08:20:00', 1.0, 0.0, '2022-06-28 16:00:00', '2022-06-27 15:03:16')
# (11, 'Ipatinga', 'MG', 'PED-114681296', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 10:28:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-25 00:06:43')
# (11, 'Ipatinga', 'MG', 'PED-114699080', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-24 10:47:00', 1.0, 0.0, '2022-06-25 16:00:00', '2022-06-24 21:34:24')
# (11, 'Ipatinga', 'MG', 'PED-115279568', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 09:15:00', 1.0, 0.0, '2022-06-28 16:00:00', '2022-06-27 21:52:55')
# (11, 'Ipatinga', 'MG', 'PED-114866888', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-25 07:15:00', 1.0, 0.0, '2022-07-07 16:00:00', '2022-07-06 20:11:47')
# (11, 'Ipatinga', 'MG', 'PED-112609688', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-18 08:31:00', 1.0, 0.0, '2022-06-19 16:00:00', '2022-06-18 20:43:11')
# (11, 'Ipatinga', 'MG', 'PED-115191560', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 07:13:00', 1.0, 0.0, '2022-06-28 16:00:00', '2022-06-27 15:05:55')
# (11, 'Ipatinga', 'MG', 'PED-115506656', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-27 15:49:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 19:47:04')
# (13, 'Ipatinga', 'MG', 'PED-13520752', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 08:16:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 22:02:05')
# (13, 'Ipatinga', 'MG', 'PED-13530328', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-11 08:43:00', 1.0, 0.0, '2022-06-12 16:00:00', '2022-06-11 19:25:40')
# (11, 'Ipatinga', 'MG', 'PED-116515328', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-30 12:06:00', 1.0, 0.0, '2022-07-01 16:00:00', '2022-07-01 04:04:51')
# (13, 'Ipatinga', 'MG', 'PED-1330096', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-02 06:36:00', 1.0, 0.0, '2022-06-03 16:00:00', '2022-06-02 16:57:06')
# (0, 'Ipatinga', 'MG', 'PED-03069336', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-26 06:41:00', 1.0, 1.0, '2022-06-27 16:00:00', '2022-06-26 17:26:09')
# (0, 'Ipatinga', 'MG', 'PED-01818984', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 10:43:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-28 19:13:59')
# (0, 'Ipatinga', 'MG', 'PED-02966280', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-25 14:42:00', 1.0, 0.0, '2022-06-29 16:00:00', '2022-06-29 04:46:03')
# (0, 'Ipatinga', 'MG', 'PED-02008680', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-23 15:48:00', 1.0, 0.0, '2022-06-24 16:00:00', '2022-06-24 11:52:33')
# (0, 'Ipatinga', 'MG', 'PED-03084840', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-26 07:33:00', 1.0, 0.0, '2022-06-27 16:00:00', '2022-06-26 11:55:54')
# (0, 'Ipatinga', 'MG', 'PED-02839512', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-25 11:31:00', 1.0, 0.0, '2022-06-26 16:00:00', '2022-06-25 16:38:16')
# (0, 'Ipatinga', 'MG', 'PED-05718696', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:39:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 19:54:53')
# (0, 'Ipatinga', 'MG', 'PED-05697264', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:10:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 14:31:57')
# (0, 'Ipatinga', 'MG', 'PED-05732376', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 07:55:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 15:52:22')
# (0, 'Ipatinga', 'MG', 'PED-05780712', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 08:42:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 17:31:17')
# (0, 'Ipatinga', 'MG', 'PED-05788920', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 08:47:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 19:54:53')
# (0, 'Ipatinga', 'MG', 'PED-06181992', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 07:01:00', 1.0, 0.0, '2022-06-05 16:00:00', '2022-06-04 20:00:01')
# (0, 'Ipatinga', 'MG', 'PED-05793480', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 08:51:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 19:54:53')
# (0, 'Ipatinga', 'MG', 'PED-06204792', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-04 07:28:00', 1.0, 1.0, '2022-06-05 16:00:00', '2022-06-04 20:00:01')
# (0, 'Ipatinga', 'MG', 'PED-05811720', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 09:03:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 14:56:47')
# (0, 'Ipatinga', 'MG', 'PED-05756544', 6986, 'TSH ULTRA SENSÍVEL', 'TSH-B', 'SANGUE', 'HORMONIO', '8,35', '2022-06-03 08:17:00', 1.0, 0.0, '2022-06-04 16:00:00', '2022-06-03 20:25:09')
